# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# PERCEPTRON PERMITE APENAS CALCULOS DISCRETOS de classificação 1 ou 0 (função limiar)

import numpy as np
from matplotlib import pyplot as plt

X = np.array([[0,0],[0,1],[1,0],[1,1]])
#Y = np.array( [0 , 1 , 1, 1]) # OR lógico
Y = np.array([0,0,0,1]) # AND lógico
#Y = np.array([0,1,1,0])# XOR lógico, como o Perceptron apenas separa as classes com uma linha reta as classes 1 e 0, e no caso do XOR temos classes que NÃO são LNEARMENTE SEPARÁVEIS (sepatrradas por uma reta)

#X = (X.dot(X.T)+1)**2  # kernel


threshold = 0.6 # limiar

n = 0.0001 # taxa de aprendizado

W = np.random.rand(np.shape(X)[1]) # INCIALIZAÇÃO ALEATÓRIA PARA MOSTRAR COMO A INCIIALIZAÇÃO AO REDOR DOS CIRUCLOS DE PESO  PODE SER DETERMINANE PARA O TEMPO DE ATUALIZAÇÃDO CODIGO
flag = 1
cont=0
while(flag==1):
    flag=0
    print('#iteration %d'%cont)
    for i in range(len(X)):
        net = X[i].dot(W)  # Somatorio peso x entrada

        if net>=threshold: # FUNÇÃO LIMIAR, SE A SOMATORIO DOS PESOS*ENTRADAS FOR MAIOR QUE O LIMIAR RECEBE 1, SE FOR MENOR RECEE ZERO -> CALCULO E FEITO PARA CADA PESO E ENTRADA INDIVIDALMENTE
            saida =1
        else:
            saida =0

        if(saida !=Y[i]): # SE A SAÍDA FOR DIFERENTE DO VALOR CORRETO, EU CONTINUO O LAÇO, CALCULANDO OS PESOS
            flag=1
            W = W + n*(Y[i] - saida)*X[i] # ATUALIZANDO O VETOR DE PESOS COM BASE NO ERRO UTILIZANDO A FORMULA DO GRADIENTE APROXIMADO Á VARIAÇÃO DOS PESOS
    cont = cont+1


plt.scatter(X[Y==0,0],X[Y==0,1])
plt.scatter(X[Y==1,0],X[Y==1,1])

X_1 = np.arange(-0.5,1.5,0.1)
X_2 = -(W[0]/W[1])*X_1 + threshold/W[1]
plt.plot(X_1,X_2)
# Out:
# #iteration 0
# #iteration 1
# #iteration 2
# #iteration 3
# #iteration 4
# #iteration 5
# #iteration 6
# #iteration 7
# #iteration 8
# #iteration 9
# #iteration 10
# #iteration 11
# #iteration 12
# #iteration 13
# #iteration 14
# #iteration 15
# #iteration 16
# #iteration 17
# #iteration 18
# #iteration 19
# #iteration 20
# #iteration 21
# #iteration 22
# #iteration 23
# #iteration 24
# #iteration 25
# #iteration 26
# #iteration 27
# #iteration 28
# #iteration 29
# #iteration 30
# #iteration 31
# #iteration 32
# #iteration 33
# #iteration 34
# #iteration 35
# #iteration 36
# #iteration 37
# #iteration 38
# #iteration 39
# #iteration 40
# #iteration 41
# #iteration 42
# #iteration 43
# #iteration 44
# #iteration 45
# #iteration 46
# #iteration 47
# #iteration 48
# #iteration 49
# #iteration 50
# #iteration 51
# #iteration 52
# #iteration 53
# #iteration 54
# #iteration 55
# #iteration 56
# #iteration 57
# #iteration 58
# #iteration 59
# #iteration 60
# #iteration 61
# #iteration 62
# ...
